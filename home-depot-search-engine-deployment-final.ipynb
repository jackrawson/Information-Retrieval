# %% [markdown]
# **Note: This notebook is an adaptation of the lab 5 & 6 notebooks, so variables and the structure of the code may seem similar**
#
# * Please run all of this code below on **Colab notebooks**

# %% [markdown]
# # Inspection of the dataset

# %%
import pandas as pd
# Full preprocessed dataset - case-folding, stop word removal, puncuation removal, and lemmatisation 
# applied to fields: product_title and product_description 
df = pd.read_csv("home_depot_trainset_preprocessed.csv", 
                 usecols = ["id", "product_uid", "product_title", 
                            "product_description", "search_term", "relevance"])
df.head()
# Out:
#    id  ...                                product_description
# 0   2  ...  angle make joint stronger also provide consist...
# 1   3  ...  angle make joint stronger also provide consist...
# 2   9  ...  behr premium textured deckover innovative soli...
# 3  16  ...  update bathroom delta vero singlehandle shower...
# 4  17  ...  update bathroom delta vero singlehandle shower...
#
# [5 rows x 6 columns]

# %%
len(df['search_term'].unique())
# Out:
# 11795

# %%
len(df['product_uid'].unique())
# Out:
# 54667

# %%
len(df)
# Out:
# 74067

# %%
# dedup dataset - keep distinct product_uid (document ids)
df2 = pd.read_csv("home_depot_trainset_preprocessed_dedup.csv", 
                 usecols = ["id", "product_uid", "product_title", 
                            "product_description", "search_term", "relevance"])
df2.head()
# Out:
#    id  ...                                product_description
# 0   2  ...  angle make joint stronger also provide consist...
# 1   9  ...  behr premium textured deckover innovative soli...
# 2  16  ...  update bathroom delta vero singlehandle shower...
# 3  18  ...  achieving delicious result almost effortless w...
# 4  23  ...  quantum adjustable 2light led black emergency ...
#
# [5 rows x 6 columns]

# %%
print(len(df), len(df2))
# Out:
# 74067 54667

# %%
len(df2['search_term'].unique())
# Out:
# 11092

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74067 entries, 0 to 74066
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   74067 non-null  int64
#  1   product_uid          74067 non-null  int64
#  2   product_title        74067 non-null  object
#  3   search_term          74067 non-null  object
#  4   relevance            74067 non-null  float64
#  5   product_description  74067 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 3.4+ MB

# %%
df2.shape
# Out:
# (54667, 6)

# %%
#drop duplicate products that are there because of the relevance data
df2 = df2.drop_duplicates(subset='product_uid')

# %%
#we now have 10824 unique products
df2.shape
# Out:
# (54667, 6)

# %% [markdown]
# # Get ready to feed into the model

# %% [markdown]
# Make sure to run each cell separately and wait for each cell to finish running in order for ElasticSearch to work properly

# %%
# !wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.0.0-linux-x86_64.tar.gz -q

# %%
# !tar -xzf elasticsearch-7.0.0-linux-x86_64.tar.gz

# %%
# !chown -R daemon:daemon elasticsearch-7.0.0

# %%
! pip install elasticsearch -q

# %%
# import elasticsearch
from elasticsearch import Elasticsearch
# start es server
import os
from subprocess import Popen, PIPE, STDOUT

es_server = Popen(['elasticsearch-7.0.0/bin/elasticsearch'], 
                  stdout=PIPE, stderr=STDOUT,
                  preexec_fn=lambda: os.setuid(1)  # as daemon need 0 not 1
                 )

# %%
# instantiating ES
def test_ES(es):
  """
  This function checks to see if we have successfully started an 
  ES instance and imported its python (version) library

  parameters:
    (es): takes in a instance of elasticsearch
  
  returns:
    boolean value of whether the instantiation is working or not
  """
  
  return es.ping()  # got True

# start and testing es 
es = Elasticsearch()
if test_ES(es):
  print('ES instance is working, now run the cells below')
else:
  print('ES instance is not working and re-run the cells above again')
# Out:
# ES instance is working, now run the cells below

# %%
# getting our dataset ready to put into the retrieval model
def ready2feed(df2):
  """
  This function separates the features of each product into separate lists
  and then combines them in a tuple 

  parameters:
    (df): pandas dataframe that is used to get our dataset in an appropriate 
          format
  
  returns:
    (list) : list containing tuples of each product where each tuple contains
             the features of the product
  """

  id, product_uid = [id for id in df2.id], [uid for uid in df2.product_uid]

  product_title, product_description = [title for title in df2.product_title], \
   [description for description in df2.product_description]

  search_term, relevance = [s_t for s_t in df2.search_term], \
  [rel for rel in df2.relevance]

  return list(zip(id, product_uid, 
                  product_title, product_description, 
                  search_term, relevance))

# testing to see if our function works
corpus = ready2feed(df2) # feed the dataset into the function
# check to see if the first product is in the right format as we intended
corpus[0]
# Out:
# (2,
#  100001,
#  'simpson strongtie 12gauge angle',
#  'angle make joint stronger also provide consistent straight corner simpson strongtie offer wide variety angle various size thickness handle lightduty job project structural connection needed bent skewed match project outdoor project moisture present use zmax zinccoated connector provide extra resistance corrosion look z end model numberversatile connector various 90 connection home repair projectsstronger angled nailing screw fastening alonehelp ensure joint consistently straight strongdimensions 3 x 3 x 112 inmade 12gauge steelgalvanized extra corrosion resistanceinstall 10d common nail 9 x 112 strongdrive sd screw',
#  'angle bracket',
#  3.0)

# %%
print(len(corpus))
# Out:
# 54667

# %% [markdown]
# # Models

# %%
# do not run this cell if this is your "first run" of the notebook
# uncomment this when you want to use another retrieval model 
# and then comment it again after running this cell
#es.indices.delete(index_name)

# %% [markdown]
# #### bm25_default

# %%
# mappings are used to define what kind of structure your data has. here explicit mapping is used: 
# https://www.elastic.co/guide/en/elasticsearch/reference/current/explicit-mapping.html

# The mapping is used when creating the index through the request body:

bm25_default = {
    'settings': {
        'number_of_shards': 1,
        'number_of_replicas': 1,
        'index': {
            'similarity': {
                'bm25_similarity': {
                    'type': 'BM25',
                    'b': '0.75',
                    'k1': '1.2'

                }
            }
        }
        
    },
    'mappings': {
          'properties': {
              'id': {'type': 'integer', 'similarity': 'bm25_similarity'},
              'product_uid': {'type': 'integer', 'similarity': 'bm25_similarity'},
              'product_title': {'type': 'text', 'similarity': 'bm25_similarity'},
              'product_description': {'type': 'text', 'similarity': 'bm25_similarity'},
              'search_term': {'type': 'text', 'similarity': 'bm25_similarity'},
              'relevance': {'type': 'float', 'similarity': 'bm25_similarity'}
          }
    }
}

# %% [markdown]
# #### bm25_high

# %%
# high values
# b = 1 corresponds to fully scaling the term weight by the document length
# full doc length normalization
bm25_high = {
    'settings': {
        'number_of_shards': 1,
        'number_of_replicas': 1,
        'index': {
            'similarity': {
                'bm25_similarity': {
                    'type': 'BM25',
                    'b': '1.0',
                    'k1': '2.0'

                }
            }
        }
        
    },
    'mappings': {
          'properties': {
              'id': {'type': 'integer', 'similarity': 'bm25_similarity'},
              'product_uid': {'type': 'integer', 'similarity': 'bm25_similarity'},
              'product_title': {'type': 'text', 'similarity': 'bm25_similarity'},
              'product_description': {'type': 'text', 'similarity': 'bm25_similarity'},
              'search_term': {'type': 'text', 'similarity': 'bm25_similarity'},
              'relevance': {'type': 'float', 'similarity': 'bm25_similarity'}
          }
    }
}

# %% [markdown]
# #### bm25_low

# %%
# low values
# b = 0 corresponds to no doc length normalization.
bm25_low = {
    'settings': {
        'number_of_shards': 1,
        'number_of_replicas': 1,
        'index': {
            'similarity': {
                'bm25_similarity': {
                    'type': 'BM25',
                    'b': '0.0',
                    'k1': '1.0'

                }
            }
        }
        
    },
    'mappings': {
          'properties': {
              'id': {'type': 'integer', 'similarity': 'bm25_similarity'},
              'product_uid': {'type': 'integer', 'similarity': 'bm25_similarity'},
              'product_title': {'type': 'text', 'similarity': 'bm25_similarity'},
              'product_description': {'type': 'text', 'similarity': 'bm25_similarity'},
              'search_term': {'type': 'text', 'similarity': 'bm25_similarity'},
              'relevance': {'type': 'float', 'similarity': 'bm25_similarity'}
          }
    }
}

# %% [markdown]
# #### dfr

# %%
# DFR
dfr = {
    'settings': {
        'number_of_shards': 1,
        'number_of_replicas': 1,
        'index': {
            'similarity': {
                'dfr_similarity': {
                    'type': 'DFR',
                    'basic_model': 'g',
                    'after_effect': 'l',
                    'normalization': 'h2',
                    'normalization.h2.c':'3.0'

                }
            }
        }
        
    },
    'mappings': {
          'properties': {
              'id': {'type': 'integer', 'similarity': 'dfr_similarity'},
              'product_uid': {'type': 'integer', 'similarity': 'dfr_similarity'},
              'product_title': {'type': 'text', 'similarity': 'dfr_similarity'},
              'product_description': {'type': 'text', 'similarity': 'dfr_similarity'},
              'search_term': {'type': 'text', 'similarity': 'dfr_similarity'},
              'relevance': {'type': 'float', 'similarity': 'dfr_similarity'}
          }
    }
}

# %% [markdown]
# # After

# %%
# run this and wait before running next cell
index_name = 'test-index'
try:
  es.indices.get(index_name)
  print('index {} already exists'.format(index_name))
except:
  print('creating index {}'.format(index_name))
  es.indices.create(index_name, body=bm25_default) # change body arguement to different retrieval models - default as seen here is bm25_default
# Out:
# creating index test-index

# %%
# now what we want to do is put some data in the index, i.e. index it: 
for id, product_uid, product_title, product_description, search_term, relevance in corpus:
  # these have the same as the mappings in the above cell
  doc_body = {
      'id': id,'product_uid': product_uid,
      'product_title': product_title,'product_description': product_description,
      'search_term': search_term, 'relevance': relevance
  }
  es.index(index_name, doc_body)

# %%
# Now let's have a look at our index: got 50 which was supposed to be 25 as ran the cell above twice so duplicated docs
print('we have made and index called {} with {} documents'.format(index_name, es.cat.count(index=index_name,h=['count'])))
# Out:
# we have made and index called test-index with 54667
#  documents

# %%
def index_info(index_name):
  #docs.count - n.o docs
  #docs.deleted - n.o docs deleted
  count, deleted, shards, =  es.cat.indices(index=index_name, h=['docs.count', 'docs.deleted', 'pri'])[:-1].split(' ')
  print(
      """
      #### INDEX INFO #####
      index_name = {}
      doc_count = {}
      shard_count = {}
      deleted_doc_count = {}
      """.format(index_name, count, shards, deleted)
  )

# %% [markdown]
# # User Interface demo
#
# Use the search on the right hand side to test given search queries.
# <br>
# **product_description** is the text field searched over.

# %%
def search(index_name, query_body):
  # return only doc_id and rank
  results = es.search(index=index_name, body=query_body, explain=False)
  plain_results = [(x['_source']['product_uid'], x['_source']['product_title'], x['_source']['relevance'], x['_score']) for x in results['hits']['hits']]
  return results, plain_results

# %%
#@title Product Search - type a search query
query = 'rain shower head'  #@param {type:"string"}
query_body = {
      'query':{
          'query_string': {
              'query': query, 
              'default_field': 'product_description'
          }
      }
  }

results, plain_results = search(index_name, query_body)
for product_id, title, relevance, score in plain_results:
    print(product_id, title, relevance, score)
# Out:
# 136785 1spray 16 raincan square ceiling mount rain ultra thin showerhead stainless steel 2.33 17.157784
# 174206 speakman 10 extension arm 2.33 16.365002
# 180868 1spray 8 filtered showerhead satin nickel led light 2.0 15.841835
# 147214 waterpik kent 7spray 6 showerhead chrome 2.67 15.726058
# 124591 vigo 6jet shower panel system rain shower head handshower stainless steel 2.33 15.169331
# 155361 kohler watertile rain 1spray 9875 overhead showerhead panel oilrubbed bronze 2.67 15.083951
# 165792 kohler watertile rain 1spray 9875 overhead showerhead brushed bronze 2.67 15.083951
# 173237 kohler watertile rain 1spray 9875 overhead showerhead polished chrome 1.67 15.083951
# 174388 grohe euphoria 1function handshower showerhead combo kit starlight chrome 2.33 14.466092
# 120585 vigo 6jet shower panel system stainless steel 2.33 14.293229

# %% [markdown]
# # Evaluation

# %%
# Retrieve distinct queries - dedup dataframe
queries = []
for i in df2['search_term'].unique():
  queries.append(i.lower())
print(len(queries))
# Out:
# 11092

# %%
# Create test list of queries
import string
queries_select = queries[:200]
queries_select = [''.join(c for c in s if c not in string.punctuation) for s in queries_select]
print(queries_select)
# Out:
# ['angle bracket', 'deck over', 'rain shower head', 'convection otr', 'emergency light', 'mdf 34', 'steele stake', 'briggs and stratton lawn mower', 'hampton bay chestnut pull up shade', 'disposer', 'grill gazebo', 'door guards', '1x1 rail decorative wood', 'lawn sprkinler', 'platform for washers', 'concrete  masonry cleaner  etcher', 'belgium block pavers', 'insulation roll', '6ft h bamboo fencing', 'chalk paint', '8 4616809045 9', '6 teir shelving', 'mortar tools', '12 boltless bracket', 'husky tool bag', 'impact driver drill battery powered', 'pellet stove', 'american standard bone round toliet', 'grayson', '6 stell', 'bolt 12 in by 12', 'elastomeric roof coating', 'outdoor dining', 'cushions outdoorlounge', 'wiremesh', 'front doors', 'kingsley moen kitchen faucet', 'roof melter', '6 kraft faced insulation', 'battery lanterns', 'planters pots', '5x5 post', 'bazz lighting', 'tiles 1212', '10  rough toilet bowl', '60 heater gallon gas water', 'shark vacuum', 'under cabinet led', 'doors exterior', '3 blue masking tape', '4x6', 'treated fence posts', '12 x 5 black pipe nipple', 'area rugs 9x12', '18  dishwasher', '30 x 60 molded one piece acrylic shower stall', 'bakers rack', 'basemetnt window', 'editing garage floor', 'car ramps ends', 'plexiglas 18 x 24', 'melnor', 'ac window unit', 'berh deck over', 'milwaukee right angle', '28 snow thower', 'gas gridlee', 'base board molding boundle', 'hampton bay set 7piece led aluminum', 'plants moses in a cradle', 'landscape edging', 'intertape duct tape 3pk', '1 black self tapping screws', '10 window sping rod', 'combo powertool kit', 'chipper', 'bidet', 'shark cleaner', 'expand it universal products', 'fiberglass repair kit', 'rug doctor carpet cleaner', 'under cabinet lighting', 'pine straw', 'andersen sliding right hand doors with blinds', '10000 btu portable ac', 'computer desk', 'tree pruner', '2 paint brush pack', 'hand sander', 'inverter generator', 'delta faucet handles', 'hot water dispenser', 'plastic tubing', 'garage chair organizer', 'face masks', 'ant killer', '5 gal buckets', 'lamp', '23 stud', 'frostking window shrink film', 'water trap moisture filter', '4   lights bulbs', 'lawn mower electic', 'closetmade', '24 stainless gas range', '48 beadboard paneling', '6x6 p sand tile', 'water heater blanket', 'funnel 6 inch', '4x4 deck post', 'closet light fixture', 'cub cadet 42', '3 way', 'dual wall ducts', 'hedge shears', 'kohler retro pedestal sink combos', 'dewalt combo kit', 'omnifilter', 'lenox diamond blades', 'cedar plank', 'colosso', 'door hinge', 'kerosene heater', 'respirator', 'kitchen  lighting', 'beer keg dispenser', 'foil board', 'malibu lights', 'satin nickel pull', 'miricale', 'galvanized framing nails', 'locks for sliding doors', 'pantry rack', 'sheetrock', 'bathrooms', 'shelf track', 'chicken wire', 'cabinet closet  100', '80 x 36 solid wood', '20v dewalt kombo', 'sheet metal', 'element for hot wa', 'aspiradora', 'fuses', 'mosaic  tiles', 'gas tubing', 'bathroom hardware knobs and pulls', 'fiberglass epoxy', 'door trim', 'bagged cinder mulch', 'door bell', 'canvas drop cloth', 'bentgrass lawn mower', 'hindges', 'lathe', 'chair molding', '2x4 board', 'fence gates', 'roller', 'clab', 'chaise', 'celling light', 'tent', 'screen frame', 'fiberglass insulation', 'dewalr tools', 'werner ladder', 'patio furniture covers', '5gallon roof patch', '14 wonderboard', 'cieling', 'chair rail moulding', '6in  by 6 inlumder', 'gates', 'masking tape', 'gilmore 34  hose', 'window insulation kit', 'ply 12', 'ceadar', 'black rock', 'molding trim', 'electric pole', 'electrolux dryer', 'barreir', 'washer dryer sets', 'bullnose tile', 'ajustable ladder feet', '2 panel door', 'milwakee m12', 'pruning saw', '60w bulb', 'ceiling scraper', 'foss rug', 'attic ladder', 'hotdipped galvanized roofing nails', '3way electrical sockets', 'martha stewart cabinet', 'cable prime line emergensy open', 'azek', '24  bathroom vanities']

# %%
# Get the declared retrieval model's scores for each product uid
from statistics import mean
output = []
for i in queries_select: # iterate through list of queries created above

  query_body = {
      'query':{
          'query_string': {
              'query': i, # i in queries list
              'default_field': 'product_description'
          }
      }
  }
  # index_name - index your searching
  results = es.search(index=index_name, body=query_body)['hits']['hits']
  result_list = []
  for hit in results:
    # BM25 is the default at the bottom of the output
    # results is a list of dicts and accessing certain keys in the dicts 
    # i.e. source which is a key with a dict as a value so accessible that dict with a key title, and acesse the score
    x = (i, hit['_source']['product_uid'], hit['_score'])
    result_list.append(x)
  output.extend(result_list)

# %%
print(len(output))
print(output)
# Out:
# 1826
# [('angle bracket', 165217, 13.302946), ('angle bracket', 165126, 12.88057), ('angle bracket', 196666, 12.88057), ('angle bracket', 120048, 12.704327), ('angle bracket', 198519, 12.657677), ('angle bracket', 102651, 12.26751), ('angle bracket', 101571, 12.118238), ('angle bracket', 185641, 11.963935), ('angle bracket', 102005, 11.483875), ('angle bracket', 200720, 11.2125025), ('deck over', 159065, 10.211855), ('deck over', 138042, 7.9596496), ('deck over', 192588, 6.6416717), ('deck over', 180318, 6.6280003), ('deck over', 182306, 6.6280003), ('deck over', 126085, 6.6127906), ('deck over', 130898, 6.6127906), ('deck over', 168842, 6.5983515), ('deck over', 128206, 6.557383), ('deck over', 112952, 6.44625), ('rain shower head', 136785, 17.157784), ('rain shower head', 174206, 16.365002), ('rain shower head', 180868, 15.841835), ('rain shower head', 147214, 15.726058), ('rain shower head', 124591, 15.169331), ('rain shower head', 155361, 15.083951), ('rain shower head', 165792, 15.083951), ('rain shower head', 173237, 15.083951), ('rain shower head', 174388, 14.466092), ('rain shower head', 120585, 14.293229), ('convection otr', 157174, 15.5432415), ('convection otr', 153874, 9.917323), ('convection otr', 108651, 9.789378), ('convection otr', 115701, 9.789378), ('convection otr', 124986, 9.789378), ('convection otr', 158341, 9.789378), ('convection otr', 117353, 9.666846), ('convection otr', 138875, 9.666846), ('convection otr', 135223, 9.391443), ('convection otr', 105026, 9.334199), ('emergency light', 115301, 12.359104), ('emergency light', 125899, 12.359104), ('emergency light', 141450, 12.359104), ('emergency light', 142422, 12.359104), ('emergency light', 203959, 12.345394), ('emergency light', 126655, 12.111983), ('emergency light', 187485, 11.927856), ('emergency light', 137999, 11.73653), ('emergency light', 164385, 11.513933), ('emergency light', 125115, 11.477354), ('mdf 34', 100865, 11.185841), ('mdf 34', 170657, 11.069078), ('mdf 34', 105914, 11.039325), ('mdf 34', 151703, 10.9389715), ('mdf 34', 131402, 10.93482), ('mdf 34', 180897, 10.612307), ('mdf 34', 111072, 10.542183), ('mdf 34', 203073, 10.12417), ('mdf 34', 151111, 9.938646), ('mdf 34', 111095, 9.806893), ('steele stake', 102221, 10.4190445), ('steele stake', 102159, 10.4190445), ('steele stake', 100695, 10.126444), ('steele stake', 100010, 9.984669), ('steele stake', 147705, 9.931687), ('steele stake', 101889, 9.793758), ('steele stake', 107409, 9.663882), ('steele stake', 164373, 9.451063), ('steele stake', 189418, 9.401519), ('steele stake', 181609, 9.222222), ('briggs and stratton lawn mower', 195471, 36.43972), ('briggs and stratton lawn mower', 157067, 28.959082), ('briggs and stratton lawn mower', 118485, 28.779163), ('briggs and stratton lawn mower', 120498, 28.779163), ('briggs and stratton lawn mower', 198919, 28.01016), ('briggs and stratton lawn mower', 171622, 27.318155), ('briggs and stratton lawn mower', 124974, 26.640572), ('briggs and stratton lawn mower', 105641, 26.189362), ('briggs and stratton lawn mower', 131633, 26.189362), ('briggs and stratton lawn mower', 125196, 25.92482), ('hampton bay chestnut pull up shade', 107841, 19.167543), ('hampton bay chestnut pull up shade', 131278, 17.66998), ('hampton bay chestnut pull up shade', 153618, 17.29999), ('hampton bay chestnut pull up shade', 153426, 17.061821), ('hampton bay chestnut pull up shade', 151574, 17.051289), ('hampton bay chestnut pull up shade', 205239, 17.051289), ('hampton bay chestnut pull up shade', 104076, 16.979626), ('hampton bay chestnut pull up shade', 128466, 16.830118), ('hampton bay chestnut pull up shade', 130202, 16.830118), ('hampton bay chestnut pull up shade', 130509, 16.830118), ('disposer', 139093, 13.817286), ('disposer', 123615, 12.713247), ('disposer', 103740, 12.028023), ('disposer', 119721, 10.884632), ('disposer', 107084, 9.539031), ('disposer', 111749, 9.42684), ('disposer', 136046, 9.042637), ('disposer', 203931, 8.709773), ('disposer', 106374, 8.3469 ...

# %%
import numpy as np
#turn output into dataframe with each query as a column, row  doc ids, and values as scores
_= pd.DataFrame(output, columns=['Query', 'Doc_ID', 'Score'])
print(len(_['Doc_ID'].unique()))
score_df = _.pivot_table(index ='Doc_ID', columns= 'Query', values = 'Score')
score_df = score_df.replace(np.nan, 0)
score_df
# Out:
# 1728
# Query   1 black self tapping screws  ...  wiremesh
# Doc_ID                               ...
# 100010                          0.0  ...       0.0
# 100016                          0.0  ...       0.0
# 100019                          0.0  ...       0.0
# 100045                          0.0  ...       0.0
# 100049                          0.0  ...       0.0
# ...                             ...  ...       ...
# 206053                          0.0  ...       0.0
# 206140                          0.0  ...       0.0
# 206243                          0.0  ...       0.0
# 206429                          0.0  ...       0.0
# 206497                          0.0  ...       0.0
#
# [1728 rows x 185 columns]

# %%
# output from df without duplicates removed for a search term 
df.loc[df['search_term'] == 'rain shower head']
# Out:
#          id  ...                                product_description
# 3        16  ...  update bathroom delta vero singlehandle shower...
# 583    1870  ...  kauai rain shower system brilliantly simple de...
# 1124   3517  ...  customize bathing experience moen halo 3spray ...
# 2120   6541  ...  glacier bay 1spray 8 square showerhead chrome ...
# 2477   7615  ...  grohe powersoul cosmopolitan shower created fu...
# 4652  14566  ...  forte singlefunction showerhead brings innovat...
# 4849  15205  ...  subtle elegant detail ignite collection create...
# 5325  16674  ...  create spalike sanctuary bathroom delta arzo 1...
#
# [8 rows x 6 columns]

# %%
# create qrels list of list from df without duplicates removed
qrels = []
for q in queries_select:  
  df_ = df.loc[df['search_term'] == q]
  product_uid = df_['product_uid'].values[:]
  search_term = df_['search_term'].values[:]
  relevance = df_['relevance'].values[:]
  qrel = []
  for i in range(len(product_uid)):
    qr = [search_term[i], product_uid[i], relevance[i]]
    qrel.append(qr)
  qrels.extend(qrel)
print('number of qrels:', len(qrels))
print(qrels)
# Out:
# number of qrels: 1380
 2.0], ['insulation roll', 102104, 2.33], ['insulation roll', 102348, 2.67], ['6ft h bamboo fencing', 100028, 2.0], ['6ft h bamboo fencing', 100155, 3.0], ['6ft h bamboo fencing', 102908, 2.67], ['6ft h bamboo fencing', 194766, 2.0], ['chalk paint', 100029, 3.0], ['chalk paint', 100288, 1.33], ['chalk paint', 100511, 2.33], ['chalk paint', 101080, 2.67], ['chalk paint', 101983, 2.67], ['8 4616809045 9', 100030, 1.67], ['8 4616809045 9', 101918, 3.0], ['8 4616809045 9', 102809, 1.67], ['8 4616809045 9', 103991, 1.33], ['8 4616809045 9', 113978, 2.0], ['8 4616809045 9', 120083, 1.67], ['8 4616809045 9', 143458, 2.0], ['8 4616809045 9', 149788, 1.33], ['8 4616809045 9', 152996, 2.33], ['6 teir shelving', 100033, 3.0], ['6 teir shelving', 139277, 2.33], ['mortar tools', 100034, 1.0], ['mortar tools', 107250, 2.67], ['mortar tools', 137719, 3.0], [' ...

# %%
# Delete search terms which did not yield results from query list and enumerate query list to give numbered query id dictionary
# left as is - approximately 185 qrels 
queries = []
for i in queries_select:
  if i in score_df.columns:
    queries.append(i)
queries = dict(enumerate(queries))
print(queries)
# Out:
# {0: 'angle bracket', 1: 'deck over', 2: 'rain shower head', 3: 'convection otr', 4: 'emergency light', 5: 'mdf 34', 6: 'steele stake', 7: 'briggs and stratton lawn mower', 8: 'hampton bay chestnut pull up shade', 9: 'disposer', 10: 'grill gazebo', 11: 'door guards', 12: '1x1 rail decorative wood', 13: 'lawn sprkinler', 14: 'platform for washers', 15: 'concrete  masonry cleaner  etcher', 16: 'belgium block pavers', 17: 'insulation roll', 18: '6ft h bamboo fencing', 19: 'chalk paint', 20: '8 4616809045 9', 21: '6 teir shelving', 22: 'mortar tools', 23: '12 boltless bracket', 24: 'husky tool bag', 25: 'impact driver drill battery powered', 26: 'pellet stove', 27: 'american standard bone round toliet', 28: 'grayson', 29: '6 stell', 30: 'bolt 12 in by 12', 31: 'elastomeric roof coating', 32: 'outdoor dining', 33: 'wiremesh', 34: 'front doors', 35: 'kingsley moen kitchen faucet', 36: 'roof melter', 37: '6 kraft faced insulation', 38: 'battery lanterns', 39: '5x5 post', 40: 'bazz lighting', 41: 'tiles 1212', 42: '10  rough toilet bowl', 43: '60 heater gallon gas water', 44: 'shark vacuum', 45: 'under cabinet led', 46: 'doors exterior', 47: '3 blue masking tape', 48: '4x6', 49: 'treated fence posts', 50: '12 x 5 black pipe nipple', 51: 'area rugs 9x12', 52: '18  dishwasher', 53: '30 x 60 molded one piece acrylic shower stall', 54: 'bakers rack', 55: 'basemetnt window', 56: 'editing garage floor', 57: 'car ramps ends', 58: 'plexiglas 18 x 24', 59: 'melnor', 60: 'ac window unit', 61: 'berh deck over', 62: 'milwaukee right angle', 63: '28 snow thower', 64: 'gas gridlee', 65: 'base board molding boundle', 66: 'hampton bay set 7piece led aluminum', 67: 'plants moses in a cradle', 68: 'landscape edging', 69: 'intertape duct tape 3pk', 70: '1 black self tapping screws', 71: '10 window sping rod', 72: 'combo powertool kit', 73: 'chipper', 74: 'bidet', 75: 'shark cleaner', 76: 'expand it universal products', 77: 'fiberglass repair kit', 78: 'rug doctor carpet cleaner', 79: 'under cabinet lighting', 80: 'pine straw', 81: 'andersen sliding right hand doors with blinds', 82: '10000 btu portable ac', 83: 'computer desk', 84: 'tree pruner', 85: '2 paint brush pack', 86: 'hand sander', 87: 'inverter generator', 88: 'delta faucet handles', 89: 'hot water dispenser', 90: 'plastic tubing', 91: 'garage chair organizer', 92: 'face masks', 93: 'ant killer', 94: '5 gal buckets', 95: 'lamp', 96: '23 stud', 97: 'frostking window shrink film', 98: 'water trap moisture filter', 99: '4   lights bulbs', 100: 'lawn mower electic', 101: '24 stainless gas range', 102: '48 beadboard paneling', 103: '6x6 p sand tile', 104: 'water heater blanket', 105: 'funnel 6 inch', 106: '4x4 deck post', 107: 'closet light fixture', 108: 'cub cadet 42', 109: '3 way', 110: 'dual wall ducts', 111: 'hedge shears', 112: 'kohler retro pedestal sink combos', 113: 'dewalt combo kit', 114: 'omnifilter', 115: 'lenox diamond blades', 116: 'cedar plank', 117: 'door hinge', 118: 'kerosene heater', 119: 'respirator', 120: 'kitchen  lighting', 121: 'beer keg dispenser', 122: 'foil board', 123: 'malibu lights', 124: 'satin nickel pull', 125: 'galvanized framing nails', 126: 'locks for sliding doors', 127: 'pantry rack', 128: 'sheetrock', 129: 'shelf track', 130: 'chicken wire', 131: 'cabinet closet  100', 132: '80 x 36 solid wood', 133: '20v dewalt kombo', 134: 'sheet metal', 135: 'element for hot wa', 136: 'mosaic  tiles', 137: 'gas tubing', 138: 'bathroom hardware knobs and pulls', 139: 'fiberglass epoxy', 140: 'door trim', 141: 'bagged cinder mulch', 142: 'door bell', 143: 'canvas drop cloth', 144: 'bentgrass lawn mower', 145: 'lathe', 146: 'chair molding', 147: '2x4 board', 148: 'fence gates', 149: 'roller', 150: 'chaise', 151: 'celling light', 152: 'tent', 153: 'screen frame', 154: 'fiberglass insulation', 155: 'werner ladder', 156: 'patio furniture covers', 157: '5gallon roof patch', 158: '14 wonderboard', 159: 'chair rail moulding', 160: '6in  by 6 inlumder', 161: 'masking tape', 162: 'gil ...

# %%
# Use above dictionary to convert search term to query id
for i in qrels:
  for key, value in queries.items():
    if value == i[0]:
      i[0] = key
print(qrels)
# Out:
# [[0, 100001, 3.0], [0, 100664, 2.67], [0, 100672, 2.33], [0, 100739, 3.0], [0, 101036, 1.33], [0, 101370, 3.0], [0, 101440, 2.33], [0, 101534, 2.33], [0, 102239, 2.67], [0, 103250, 3.0], [0, 103262, 3.0], [1, 100002, 3.0], [1, 100092, 1.67], [1, 101629, 3.0], [1, 101795, 2.67], [1, 103015, 1.67], [1, 103057, 2.33], [1, 103356, 2.67], [1, 103384, 2.33], [2, 100005, 2.33], [2, 100331, 2.67], [2, 100616, 3.0], [2, 101126, 3.0], [2, 101287, 3.
# %%
def retrieve_ranking(query, score_df):
  q_terms_only = score_df[query]
  return sorted(zip(score_df.index.values,q_terms_only.values), key = lambda tup:tup[1], reverse=True)

# %%
# To retrieve and calculate accuracy metrics for each query lets loop over them
k = 10

precision_scores = []
for query_id, query in queries.items():
  doc_ranking = retrieve_ranking(query, score_df)
  retrieved = [doc[0] for doc in doc_ranking[:k]] # take only the document id, rather than score
  qrels_query = [qrel for qrel in qrels_ if qrel[0] == query_id]
  relevant_doc_ids = [qrel[1] for qrel in qrels_query if qrel[-1] == 1]
  non_relevant_doc_ids = [qrel[1] for qrel in qrels_query if qrel[-1] == 0]
  TP = len(set(retrieved) & set(relevant_doc_ids))
  FP = len(set(retrieved) & set(non_relevant_doc_ids))
  FN = len(set(relevant_doc_ids) - set(retrieved))
  if TP or FP != 0:
    precision = (TP) / (TP + FP)
  else:
    precision = 0
  if TP or FN != 0:
    recall = (TP) / (TP + FN)
  else:
    recall = 0
  if precision or recall != 0:
    f1 = 2 * precision * recall / (precision + recall)
  else:
    f1 = 0
  precision_scores.append(precision)

  print('For the query:', query, 'TP: ', TP, 'FP: ', FP, 'FN: ', FN, ' precision:', precision, ',recall:', recall, 'f1:', f1)
# Out:
# For the query: angle bracket TP:  0 FP:  0 FN:  10  precision: 0 ,recall: 0.0 f1: 0
# For the query: deck over TP:  0 FP:  0 FN:  6  precision: 0 ,recall: 0.0 f1: 0
# For the query: rain shower head TP:  0 FP:  0 FN:  8  precision: 0 ,recall: 0.0 f1: 0
# For the query: convection otr TP:  0 FP:  0 FN:  7  precision: 0 ,recall: 0.0 f1: 0
# For the query: emergency light TP:  0 FP:  0 FN:  9  precision: 0 ,recall: 0.0 f1: 0
# For the query: mdf 34 TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: steele stake TP:  2 FP:  0 FN:  5  precision: 1.0 ,recall: 0.2857142857142857 f1: 0.4444444444444445
# For the query: briggs and stratton lawn mower TP:  1 FP:  0 FN:  2  precision: 1.0 ,recall: 0.3333333333333333 f1: 0.5
# For the query: hampton bay chestnut pull up shade TP:  0 FP:  0 FN:  2  precision: 0 ,recall: 0.0 f1: 0
# For the query: disposer TP:  2 FP:  2 FN:  4  precision: 0.5 ,recall: 0.3333333333333333 f1: 0.4
# For the query: grill gazebo TP:  4 FP:  0 FN:  0  precision: 1.0 ,recall: 1.0 f1: 1.0
# For the query: door guards TP:  0 FP:  0 FN:  6  precision: 0 ,recall: 0.0 f1: 0
# For the query: 1x1 rail decorative wood TP:  0 FP:  0 FN:  1  precision: 0 ,recall: 0.0 f1: 0
# For the query: lawn sprkinler TP:  0 FP:  0 FN:  6  precision: 0 ,recall: 0.0 f1: 0
# For the query: platform for washers TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: concrete  masonry cleaner  etcher TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: belgium block pavers TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: insulation roll TP:  4 FP:  0 FN:  5  precision: 1.0 ,recall: 0.4444444444444444 f1: 0.6153846153846153
# For the query: 6ft h bamboo fencing TP:  2 FP:  0 FN:  2  precision: 1.0 ,recall: 0.5 f1: 0.6666666666666666
# For the query: chalk paint TP:  0 FP:  0 FN:  4  precision: 0 ,recall: 0.0 f1: 0
# For the query: 8 4616809045 9 TP:  0 FP:  0 FN:  4  precision: 0 ,recall: 0.0 f1: 0
# For the query: 6 teir shelving TP:  0 FP:  0 FN:  2  precision: 0 ,recall: 0.0 f1: 0
# For the query: mortar tools TP:  0 FP:  0 FN:  3  precision: 0 ,recall: 0.0 f1: 0
# For the query: 12 boltless bracket TP:  0 FP:  0 FN:  10  precision: 0 ,recall: 0.0 f1: 0
# For the query: husky tool bag TP:  4 FP:  0 FN:  5  precision: 1.0 ,recall: 0.4444444444444444 f1: 0.6153846153846153
# For the query: impact driver drill battery powered TP:  0 FP:  0 FN:  4  precision: 0 ,recall: 0.0 f1: 0
# For the query: pellet stove TP:  0 FP:  0 FN:  9  precision: 0 ,recall: 0.0 f1: 0
# For the query: american standard bone round toliet TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: grayson TP:  4 FP:  0 FN:  1  precision: 1.0 ,recall: 0.8 f1: 0.888888888888889
# For the query: 6 stell TP:  0 FP:  0 FN:  4  precision: 0 ,recall: 0.0 f1: 0
# For the query: bolt 12 in by 12 TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: elastomeric roof coating TP:  7 FP:  0 FN:  3  precision: 1.0 ,recall: 0.7 f1: 0.8235294117647058
# For the query: outdoor dining TP:  1 FP:  0 FN:  8  precision: 1.0 ,recall: 0.1111111111111111 f1: 0.19999999999999998
# For the query: wiremesh TP:  0 FP:  0 FN:  8  precision: 0 ,recall: 0.0 f1: 0
# For the query: front doors TP:  0 FP:  0 FN:  8  precision: 0 ,recall: 0.0 f1: 0
# For the query: kingsley moen kitchen faucet TP:  0 FP:  0 FN:  9  precision: 0 ,recall: 0.0 f1: 0
# For the query: roof melter TP:  1 FP:  2 FN:  3  precision: 0.3333333333333333 ,recall: 0.25 f1: 0.28571428571428575
# For the query: 6 kraft faced insulation TP:  1 FP:  1 FN:  0  precision: 0.5 ,recall: 1.0 f1: 0.6666666666666666
# For the query: battery lanterns TP:  1 FP:  0 FN:  3  precision: 1.0 ,recall: 0.25 f1: 0.4
# For the query: 5x5 post TP:  0 FP:  0 FN:  10  precision: 0 ,recall: 0.0 f1: 0
# For the query: bazz lighting TP:  5 FP:  0 FN:  3  precision: 1.0 ,recall: 0.625 f1: 0.7692307692307693
# For the query: tiles 1212 TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: 10  rough toilet bowl TP:  1 FP:  0 FN:  1  precision: 1.0 ,recall: 0.5 f1: 0.6666666666666666
# For the query: 60 heater gallon gas water TP:  0 FP:  0 FN:  1  precision: 0 ,recall: 0.0 f1: 0
# For the query: shark vacuum TP:  3 FP:  0 FN:  2  precision: 1.0 ,recall: 0.6 f1: 0.7499999999999999
# For the query: under cabinet led TP:  1 FP:  0 FN:  8  precision: 1.0 ,recall: 0.1111111111111111 f1: 0.19999999999999998
# For the query: doors exterior TP:  0 FP:  0 FN:  10  precision: 0 ,recall: 0.0 f1: 0
# For the query: 3 blue masking tape TP:  0 FP:  0 FN:  5  precision: 0 ,recall: 0.0 f1: 0
# For the query: 4x6 TP:  0 FP:  0 FN:  6  precision: 0 ,recall: 0.0 f1: 0
# For the query: treated fence posts TP:  0 FP:  0 FN:  7  precision: 0 ,recall: 0.0 f1: 0
# For the query: 12 x 5 black pipe nipple TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: area rugs 9x12 TP:  0 FP:  0 FN:  8  precision: 0 ,recall: 0.0 f1: 0
# For the query: 18  dishwasher TP:  2 FP:  0 FN:  2  precision: 1.0 ,recall: 0.5 f1: 0.6666666666666666
# For the query: 30 x 60 molded one piece acrylic shower stall TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: bakers rack TP:  0 FP:  0 FN:  10  precision: 0 ,recall: 0.0 f1: 0
# For the query: basemetnt window TP:  0 FP:  0 FN:  5  precision: 0 ,recall: 0.0 f1: 0
# For the query: editing garage floor TP:  3 FP:  0 FN:  8  precision: 1.0 ,recall: 0.2727272727272727 f1: 0.42857142857142855
# For the query: car ramps ends TP:  0 FP:  0 FN:  10  precision: 0 ,recall: 0.0 f1: 0
# For the query: plexiglas 18 x 24 TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: melnor TP:  3 FP:  0 FN:  8  precision: 1.0 ,recall: 0.2727272727272727 f1: 0.42857142857142855
# For the query: ac window unit TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: berh deck over TP:  0 FP:  0 FN:  8  precision: 0 ,recall: 0.0 f1: 0
# For the query: milwaukee right angle TP:  2 FP:  0 FN:  9  precision: 1.0 ,recall: 0.18181818181818182 f1: 0.3076923076923077
# For the query: 28 snow thower TP:  3 FP:  0 FN:  2  precision: 1.0 ,recall: 0.6 f1: 0.7499999999999999
# For the query: gas gridlee TP:  0 FP:  0 FN:  7  precision: 0 ,recall: 0.0 f1: 0
# For the query: base board molding boundle TP:  0 FP:  1 FN:  6  precision: 0.0 ,recall: 0.0 f1: 0
# For the query: hampton bay set 7piece led aluminum TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: plants moses in a cradle TP:  0 FP:  0 FN:  6  precision: 0 ,recall: 0.0 f1: 0
# For the query: landscape edging TP:  1 FP:  0 FN:  4  precision: 1.0 ,recall: 0.2 f1: 0.33333333333333337
# For the query: intertape duct tape 3pk TP:  0 FP:  0 FN:  6  precision: 0 ,recall: 0.0 f1: 0
# For the query: 1 black self tapping screws TP:  1 FP:  0 FN:  9  precision: 1.0 ,recall: 0.1 f1: 0.18181818181818182
# For the query: 10 window sping rod TP:  0 FP:  0 FN:  3  precision: 0 ,recall: 0.0 f1: 0
# For the query: combo powertool kit TP:  0 FP:  0 FN:  4  precision: 0 ,recall: 0.0 f1: 0
# For the query: chipper TP:  2 FP:  0 FN:  4  precision: 1.0 ,recall: 0.3333333333333333 f1: 0.5
# For the query: bidet TP:  2 FP:  1 FN:  7  precision: 0.6666666666666666 ,recall: 0.2222222222222222 f1: 0.3333333333333333
# For the query: shark cleaner TP:  1 FP:  0 FN:  3  precision: 1.0 ,recall: 0.25 f1: 0.4
# For the query: expand it universal products TP:  0 FP:  0 FN:  1  precision: 0 ,recall: 0.0 f1: 0
# For the query: fiberglass repair kit TP:  1 FP:  0 FN:  5  precision: 1.0 ,recall: 0.16666666666666666 f1: 0.2857142857142857
# For the query: rug doctor carpet cleaner TP:  6 FP:  0 FN:  0  precision: 1.0 ,recall: 1.0 f1: 1.0
# For the query: under cabinet lighting TP:  0 FP:  0 FN:  8  precision: 0 ,recall: 0.0 f1: 0
# For the query: pine straw TP:  3 FP:  0 FN:  1  precision: 1.0 ,recall: 0.75 f1: 0.8571428571428571
# For the query: andersen sliding right hand doors with blinds TP:  0 FP:  0 FN:  8  precision: 0 ,recall: 0.0 f1: 0
# For the query: 10000 btu portable ac TP:  1 FP:  0 FN:  2  precision: 1.0 ,recall: 0.3333333333333333 f1: 0.5
# For the query: computer desk TP:  3 FP:  0 FN:  8  precision: 1.0 ,recall: 0.2727272727272727 f1: 0.42857142857142855
# For the query: tree pruner TP:  4 FP:  0 FN:  6  precision: 1.0 ,recall: 0.4 f1: 0.5714285714285715
# For the query: 2 paint brush pack TP:  5 FP:  0 FN:  0  precision: 1.0 ,recall: 1.0 f1: 1.0
# For the query: hand sander TP:  3 FP:  0 FN:  3  precision: 1.0 ,recall: 0.5 f1: 0.6666666666666666
# For the query: inverter generator TP:  2 FP:  0 FN:  4  precision: 1.0 ,recall: 0.3333333333333333 f1: 0.5
# For the query: delta faucet handles TP:  0 FP:  0 FN:  12  precision: 0 ,recall: 0.0 f1: 0
# For the query: hot water dispenser TP:  1 FP:  0 FN:  11  precision: 1.0 ,recall: 0.08333333333333333 f1: 0.15384615384615385
# For the query: plastic tubing TP:  2 FP:  0 FN:  5  precision: 1.0 ,recall: 0.2857142857142857 f1: 0.4444444444444445
# For the query: garage chair organizer TP:  0 FP:  0 FN:  4  precision: 0 ,recall: 0.0 f1: 0
# For the query: face masks TP:  0 FP:  0 FN:  3  precision: 0 ,recall: 0.0 f1: 0
# For the query: ant killer TP:  1 FP:  0 FN:  2  precision: 1.0 ,recall: 0.3333333333333333 f1: 0.5
# For the query: 5 gal buckets TP:  1 FP:  0 FN:  5  precision: 1.0 ,recall: 0.16666666666666666 f1: 0.2857142857142857
# For the query: lamp TP:  0 FP:  0 FN:  7  precision: 0 ,recall: 0.0 f1: 0
# For the query: 23 stud TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: frostking window shrink film TP:  1 FP:  0 FN:  2  precision: 1.0 ,recall: 0.3333333333333333 f1: 0.5
# For the query: water trap moisture filter TP:  0 FP:  0 FN:  6  precision: 0 ,recall: 0.0 f1: 0
# For the query: 4   lights bulbs TP:  0 FP:  0 FN:  5  precision: 0 ,recall: 0.0 f1: 0
# For the query: lawn mower electic TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: 24 stainless gas range TP:  1 FP:  0 FN:  4  precision: 1.0 ,recall: 0.2 f1: 0.33333333333333337
# For the query: 48 beadboard paneling TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: 6x6 p sand tile TP:  0 FP:  0 FN:  4  precision: 0 ,recall: 0.0 f1: 0
# For the query: water heater blanket TP:  7 FP:  0 FN:  0  precision: 1.0 ,recall: 1.0 f1: 1.0
# For the query: funnel 6 inch TP:  0 FP:  0 FN:  1  precision: 0 ,recall: 0.0 f1: 0
# For the query: 4x4 deck post TP:  0 FP:  0 FN:  6  precision: 0 ,recall: 0.0 f1: 0
# For the query: closet light fixture TP:  1 FP:  0 FN:  6  precision: 1.0 ,recall: 0.14285714285714285 f1: 0.25
# For the query: cub cadet 42 TP:  5 FP:  0 FN:  8  precision: 1.0 ,recall: 0.38461538461538464 f1: 0.5555555555555556
# For the query: 3 way TP:  0 FP:  0 FN:  12  precision: 0 ,recall: 0.0 f1: 0
# For the query: dual wall ducts TP:  0 FP:  0 FN:  4  precision: 0 ,recall: 0.0 f1: 0
# For the query: hedge shears TP:  0 FP:  0 FN:  3  precision: 0 ,recall: 0.0 f1: 0
# For the query: kohler retro pedestal sink combos TP:  2 FP:  0 FN:  8  precision: 1.0 ,recall: 0.2 f1: 0.33333333333333337
# For the query: dewalt combo kit TP:  1 FP:  0 FN:  5  precision: 1.0 ,recall: 0.16666666666666666 f1: 0.2857142857142857
# For the query: omnifilter TP:  8 FP:  0 FN:  4  precision: 1.0 ,recall: 0.6666666666666666 f1: 0.8
# For the query: lenox diamond blades TP:  0 FP:  0 FN:  9  precision: 0 ,recall: 0.0 f1: 0
# For the query: cedar plank TP:  3 FP:  0 FN:  6  precision: 1.0 ,recall: 0.3333333333333333 f1: 0.5
# For the query: door hinge TP:  0 FP:  0 FN:  7  precision: 0 ,recall: 0.0 f1: 0
# For the query: kerosene heater TP:  3 FP:  1 FN:  1  precision: 0.75 ,recall: 0.75 f1: 0.75
# For the query: respirator TP:  2 FP:  0 FN:  2  precision: 1.0 ,recall: 0.5 f1: 0.6666666666666666
# For the query: kitchen  lighting TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: beer keg dispenser TP:  7 FP:  0 FN:  2  precision: 1.0 ,recall: 0.7777777777777778 f1: 0.8750000000000001
# For the query: foil board TP:  0 FP:  0 FN:  2  precision: 0 ,recall: 0.0 f1: 0
# For the query: malibu lights TP:  2 FP:  0 FN:  7  precision: 1.0 ,recall: 0.2222222222222222 f1: 0.3636363636363636
# For the query: satin nickel pull TP:  2 FP:  0 FN:  8  precision: 1.0 ,recall: 0.2 f1: 0.33333333333333337
# For the query: galvanized framing nails TP:  2 FP:  0 FN:  4  precision: 1.0 ,recall: 0.3333333333333333 f1: 0.5
# For the query: locks for sliding doors TP:  0 FP:  0 FN:  8  precision: 0 ,recall: 0.0 f1: 0
# For the query: pantry rack TP:  0 FP:  0 FN:  6  precision: 0 ,recall: 0.0 f1: 0
# For the query: sheetrock TP:  2 FP:  0 FN:  3  precision: 1.0 ,recall: 0.4 f1: 0.5714285714285715
# For the query: shelf track TP:  3 FP:  0 FN:  8  precision: 1.0 ,recall: 0.2727272727272727 f1: 0.42857142857142855
# For the query: chicken wire TP:  1 FP:  2 FN:  7  precision: 0.3333333333333333 ,recall: 0.125 f1: 0.18181818181818182
# For the query: cabinet closet  100 TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: 80 x 36 solid wood TP:  0 FP:  0 FN:  6  precision: 0 ,recall: 0.0 f1: 0
# For the query: 20v dewalt kombo TP:  0 FP:  0 FN:  11  precision: 0 ,recall: 0.0 f1: 0
# For the query: sheet metal TP:  0 FP:  0 FN:  9  precision: 0 ,recall: 0.0 f1: 0
# For the query: element for hot wa TP:  0 FP:  1 FN:  8  precision: 0.0 ,recall: 0.0 f1: 0
# For the query: mosaic  tiles TP:  0 FP:  0 FN:  9  precision: 0 ,recall: 0.0 f1: 0
# For the query: gas tubing TP:  0 FP:  0 FN:  8  precision: 0 ,recall: 0.0 f1: 0
# For the query: bathroom hardware knobs and pulls TP:  0 FP:  0 FN:  12  precision: 0 ,recall: 0.0 f1: 0
# For the query: fiberglass epoxy TP:  1 FP:  0 FN:  4  precision: 1.0 ,recall: 0.2 f1: 0.33333333333333337
# For the query: door trim TP:  0 FP:  0 FN:  10  precision: 0 ,recall: 0.0 f1: 0
# For the query: bagged cinder mulch TP:  0 FP:  0 FN:  9  precision: 0 ,recall: 0.0 f1: 0
# For the query: door bell TP:  0 FP:  0 FN:  8  precision: 0 ,recall: 0.0 f1: 0
# For the query: canvas drop cloth TP:  4 FP:  0 FN:  3  precision: 1.0 ,recall: 0.5714285714285714 f1: 0.7272727272727273
# For the query: bentgrass lawn mower TP:  0 FP:  0 FN:  9  precision: 0 ,recall: 0.0 f1: 0
# For the query: lathe TP:  4 FP:  0 FN:  4  precision: 1.0 ,recall: 0.5 f1: 0.6666666666666666
# For the query: chair molding TP:  1 FP:  0 FN:  10  precision: 1.0 ,recall: 0.09090909090909091 f1: 0.16666666666666669
# For the query: 2x4 board TP:  0 FP:  0 FN:  10  precision: 0 ,recall: 0.0 f1: 0
# For the query: fence gates TP:  0 FP:  0 FN:  7  precision: 0 ,recall: 0.0 f1: 0
# For the query: roller TP:  0 FP:  1 FN:  3  precision: 0.0 ,recall: 0.0 f1: 0
# For the query: chaise TP:  2 FP:  0 FN:  5  precision: 1.0 ,recall: 0.2857142857142857 f1: 0.4444444444444445
# For the query: celling light TP:  0 FP:  0 FN:  2  precision: 0 ,recall: 0.0 f1: 0
# For the query: tent TP:  0 FP:  0 FN:  7  precision: 0 ,recall: 0.0 f1: 0
# For the query: screen frame TP:  0 FP:  3 FN:  5  precision: 0.0 ,recall: 0.0 f1: 0
# For the query: fiberglass insulation TP:  2 FP:  0 FN:  7  precision: 1.0 ,recall: 0.2222222222222222 f1: 0.3636363636363636
# For the query: werner ladder TP:  1 FP:  2 FN:  4  precision: 0.3333333333333333 ,recall: 0.2 f1: 0.25
# For the query: patio furniture covers TP:  0 FP:  0 FN:  9  precision: 0 ,recall: 0.0 f1: 0
# For the query: 5gallon roof patch TP:  2 FP:  0 FN:  1  precision: 1.0 ,recall: 0.6666666666666666 f1: 0.8
# For the query: 14 wonderboard TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: chair rail moulding TP:  1 FP:  0 FN:  9  precision: 1.0 ,recall: 0.1 f1: 0.18181818181818182
# For the query: 6in  by 6 inlumder TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: masking tape TP:  5 FP:  0 FN:  5  precision: 1.0 ,recall: 0.5 f1: 0.6666666666666666
# For the query: gilmore 34  hose TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: window insulation kit TP:  2 FP:  0 FN:  2  precision: 1.0 ,recall: 0.5 f1: 0.6666666666666666
# For the query: ply 12 TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: black rock TP:  0 FP:  0 FN:  7  precision: 0 ,recall: 0.0 f1: 0
# For the query: molding trim TP:  0 FP:  0 FN:  7  precision: 0 ,recall: 0.0 f1: 0
# For the query: electric pole TP:  0 FP:  0 FN:  5  precision: 0 ,recall: 0.0 f1: 0
# For the query: electrolux dryer TP:  5 FP:  0 FN:  2  precision: 1.0 ,recall: 0.7142857142857143 f1: 0.8333333333333333
# For the query: washer dryer sets TP:  0 FP:  0 FN:  7  precision: 0 ,recall: 0.0 f1: 0
# For the query: bullnose tile TP:  1 FP:  0 FN:  10  precision: 1.0 ,recall: 0.09090909090909091 f1: 0.16666666666666669
# For the query: ajustable ladder feet TP:  0 FP:  0 FN:  4  precision: 0 ,recall: 0.0 f1: 0
# For the query: 2 panel door TP:  0 FP:  0 FN:  8  precision: 0 ,recall: 0.0 f1: 0
# For the query: milwakee m12 TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: pruning saw TP:  3 FP:  1 FN:  2  precision: 0.75 ,recall: 0.6 f1: 0.6666666666666665
# For the query: 60w bulb TP:  2 FP:  0 FN:  7  precision: 1.0 ,recall: 0.2222222222222222 f1: 0.3636363636363636
# For the query: ceiling scraper TP:  2 FP:  0 FN:  2  precision: 1.0 ,recall: 0.5 f1: 0.6666666666666666
# For the query: foss rug TP:  0 FP:  0 FN:  5  precision: 0 ,recall: 0.0 f1: 0
# For the query: attic ladder TP:  3 FP:  0 FN:  5  precision: 1.0 ,recall: 0.375 f1: 0.5454545454545454
# For the query: hotdipped galvanized roofing nails TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: 3way electrical sockets TP:  0 FP:  0 FN:  0  precision: 0 ,recall: 0 f1: 0
# For the query: martha stewart cabinet TP:  0 FP:  0 FN:  8  precision: 0 ,recall: 0.0 f1: 0
# For the query: cable prime line emergensy open TP:  0 FP:  0 FN:  6  precision: 0 ,recall: 0.0 f1: 0
# For the query: azek TP:  6 FP:  1 FN:  0  precision: 0.8571428571428571 ,recall: 1.0 f1: 0.923076923076923
# For the query: 24  bathroom vanities TP:  0 FP:  0 FN:  7  precision: 0 ,recall: 0.0 f1: 0

# %%
# Calculate mean average precision from precision scores for every query for the chosen model
sum_pre = sum(precision_scores)
map = sum_pre/len(queries_select)
print('mean average precision: ',map)
# Out:
# mean average precision:  0.36011904761904767
